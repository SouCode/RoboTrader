# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns



yf.set_tz_cache_location("/Users/sou/EngineerSou/AlgoTrade/cache")

# %%
ticker=['SPY', 'AAPL', 'KO']
stocks = yf.download(ticker, start = '2010-01-01',end = '2023-01-30')
stocks
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487534  18.645309   87.483215    7.643214  28.520000
# 2010-01-05    6.498751  18.419762   87.714783    7.656429  28.174999
# 2010-01-06    6.395379  18.413227   87.776543    7.534643  28.165001
# 2010-01-07    6.383555  18.367458   88.147064    7.520714  28.094999
# 2010-01-08    6.425996  18.027500   88.440376    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2023-01-23  140.510513  58.852821  396.232117  141.110001  60.230000
# 2023-01-24  141.924484  59.165504  395.806885  142.529999  60.549999
# 2023-01-25  141.257324  59.536819  395.955200  141.860001  60.930000
# 2023-01-26  143.348419  59.419563  400.306915  143.960007  60.810001
# ...

# %%
stocks.to_csv('souPicks.csv', index=False)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2022-01-03  180.190948  56.279057  464.923401  182.009995  59.299999
# 2022-01-04  177.904068  57.218620  464.767670  179.699997  60.290001
# 2022-01-05  173.171829  57.693153  455.843109  174.919998  60.790001
# 2022-01-06  170.281006  57.389454  455.414856  172.000000  60.470001
# 2022-01-07  170.449310  57.256580  453.614380  172.169998  60.330002
# 2022-01-10  170.469131  57.351490  453.049957  172.190002  60.430000
# 2022-01-11  173.330231  57.370472  457.176453  175.080002  60.450001
# 2022-01-12  173.775726  57.455879  458.412445  175.529999  60.540001
# 2022-01-13  170.469131  57.797546  452.096191  172.190002  60.900002
# 2022-01-14  171.340332  58.262581  452.281128  173.070007  61.389999
# 2022-01-18  168.103012  57.797546  444.271362  169.800003  60.900002
# ...

# %%
stocks = pd.read_csv('souPicks.csv')
stocks
# Out:
#              Adj Close         Adj Close.1         Adj Close.2  \
# 0                 AAPL                  KO                 SPY
# 1   180.19097900390625  56.279056549072266   464.9233703613281
# 2   177.90406799316406  57.218624114990234   464.7676696777344
# 3    173.1718292236328   57.69314956665039  455.84307861328125
# 4     170.281005859375   57.38945770263672   455.4149169921875
# 5   170.44931030273438    57.2565803527832   453.6143798828125
# 6    170.4691162109375   57.35148239135742   453.0499572753906
# 7   173.33023071289062    57.3704719543457  457.17645263671875
# 8   173.77572631835938   57.45587921142578   458.4124755859375
# 9    170.4691162109375  57.797550201416016     452.09619140625
# 10     171.34033203125  58.262577056884766   452.2810974121094
# 11  168.10301208496094  57.797550201416016   444.2713317871094
# 12   164.5686798095703   57.89244842529297   439.6582336425781
# 13   162.8658447265625   57.65517807006836  434.79205322265625
# ...

# %%
# Create a Tickers object for multiple tickers
tickers = yf.Tickers('msft aapl goog')

# Create a dictionary to store the info of each ticker
info_dict = {}


for ticker in tickers.tickers:
    info_dict[ticker] = tickers.tickers[ticker].info

# Convert the dictionary to a DataFrame
info_df = pd.DataFrame.from_dict(info_dict, orient='index')

# Display the DataFrame
info_df
# Out:
#                        address1           city state         zip  \
# MSFT          One Microsoft Way        Redmond    WA  98052-6399
# AAPL         One Apple Park Way      Cupertino    CA       95014
# GOOG  1600 Amphitheatre Parkway  Mountain View    CA       94043
#
#             country         phone                    website  \
# MSFT  United States  425 882 8080  https://www.microsoft.com
# AAPL  United States  408 996 1010      https://www.apple.com
# GOOG  United States  650 253 0000        https://www.abc.xyz
#
#                             industry                   industryKey  \
# MSFT       Software - Infrastructure       software-infrastructure
# AAPL            Consumer Electronics          consumer-electronics
# GOOG  Internet Content & Information  internet-content-information
#
#                         industryDisp  ... freeCashflow operatingCashflow  \
# MSFT       Software - Infrastructure  ...  50418876416       94966996992
# ...

# %%
#optional
msft_info = tickers.tickers['MSFT'].info
df_msft = pd.DataFrame.from_dict(msft_info, orient='index', columns=['MSFT'])
df_msft
# Out:
#                                 MSFT
# address1           One Microsoft Way
# city                         Redmond
# state                             WA
# zip                       98052-6399
# country                United States
# ...                              ...
# grossMargins                 0.69441
# ebitdaMargins                0.49714
# operatingMargins             0.47587
# financialCurrency                USD
# trailingPegRatio              2.3187
#
# [131 rows x 1 columns]

# %%
tickers.tickers['GOOG'].actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-03-27 00:00:00-04:00        0.0      2.002000
# 2015-04-27 00:00:00-04:00        0.0      1.002746
# 2022-07-18 00:00:00-04:00        0.0     20.000000

# %%
stocks.columns=stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index(['Adj Close', 'Adj Close.1', 'Adj Close.2', 'Close', 'Close.1',
#        'Close.2', 'High', 'High.1', 'High.2', 'Low', 'Low.1', 'Low.2', 'Open',
#        'Open.1', 'Open.2', 'Volume', 'Volume.1', 'Volume.2'],
#       dtype='object')

# %%
stocks.describe()
# Out:
#                 Adj Close         Adj Close.1 Adj Close.2               Close  \
# count                  20                  20          20                  20
# unique                 19                  18          20                  19
# top     170.4691162109375  57.797550201416016         SPY  172.19000244140625
# freq                    2                   2           1                   2
#
#                    Close.1 Close.2  High              High.1 High.2   Low  \
# count                   20      20    20                  20     20    20
# unique                  18      20    20                  19     20    20
# top     60.900001525878906     SPY  AAPL  60.349998474121094    SPY  AAPL
# freq                     2       1     1                   2      1     1
#
#        Low.1 Low.2  Open Open.1 Open.2 Volume Volume.1 Volume.2
# count     20    20    20     20     20     20       20       20
# unique    20    20    20     20     20     20       20       20
# ...

# %%
stocks['Close'] = pd.to_numeric(stocks['Close'], errors='coerce')

close = stocks[['Close']]
close
# Out:
#          Close
# 0          NaN
# 1   182.009995
# 2   179.699997
# 3   174.919998
# 4   172.000000
# 5   172.169998
# 6   172.190002
# 7   175.080002
# 8   175.529999
# 9   172.190002
# 10  173.070007
# 11  169.800003
# 12  166.229996
# 13  164.509995
# 14  162.410004
# 15  161.619995
# 16  159.779999
# 17  159.690002
# 18  159.220001
# 19  170.330002

# %%
# Extract the 'Close' values for each ticker
close_values = stocks['Close']
close_values
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2023-01-23  141.110001  60.230000  400.630005
# 2023-01-24  142.529999  60.549999  400.200012
# 2023-01-25  141.860001  60.930000  400.350006
# 2023-01-26  143.960007  60.810001  404.750000
# 2023-01-27  145.929993  60.490002  405.679993
#
# [3290 rows x 3 columns]

# %%
# %matplotlib inline
plt.style.use('ggplot')

# %%
close_values.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
close_values.iloc[0,0]
# Out:
# 182.00999450683594

# %%
close_values.AAPL
# Out:
# Date
# 2022-01-03    182.009995
# 2022-01-04    179.699997
# 2022-01-05    174.919998
# 2022-01-06    172.000000
# 2022-01-07    172.169998
#                  ...
# 2023-01-23    141.110001
# 2023-01-24    142.529999
# 2023-01-25    141.860001
# 2023-01-26    143.960007
# 2023-01-27    145.929993
# Name: AAPL, Length: 269, dtype: float64

# %%
close_values.AAPL.div(close_values.iloc[0,0])
# Out:
# Date
# 2022-01-03    1.000000
# 2022-01-04    0.987308
# 2022-01-05    0.961046
# 2022-01-06    0.945003
# 2022-01-07    0.945937
#                 ...
# 2023-01-23    0.775287
# 2023-01-24    0.783089
# 2023-01-25    0.779408
# 2023-01-26    0.790946
# 2023-01-27    0.801769
# Name: AAPL, Length: 269, dtype: float64

# %%
close_values.AAPL.div(close_values.iloc[0,0]).mul(100)
# Out:
# Date
# 2022-01-03    100.000000
# 2022-01-04     98.730840
# 2022-01-05     96.104612
# 2022-01-06     94.500305
# 2022-01-07     94.593705
#                  ...
# 2023-01-23     77.528710
# 2023-01-24     78.308886
# 2023-01-25     77.940775
# 2023-01-26     79.094561
# 2023-01-27     80.176912
# Name: AAPL, Length: 269, dtype: float64

# %%
close_values.iloc[0]
# Out:
# AAPL    182.009995
# KO       59.299999
# SPY     477.709991
# Name: 2022-01-03 00:00:00, dtype: float64

# %%
normClose = close_values.div(close_values.iloc[0,0]).mul(100)
normClose
# Out:
#                    AAPL          KO          SPY
# Date
# 2010-01-04   100.000000  373.141451  1482.753178
# 2010-01-05   100.172893  368.627627  1486.678168
# 2010-01-06    98.579511  368.496814  1487.724872
# 2010-01-07    98.397266  367.580948  1494.004997
# 2010-01-08    99.051443  360.777547  1498.976691
# ...                 ...         ...          ...
# 2023-01-23  1846.212816  788.019252  5241.643019
# 2023-01-24  1864.791364  792.205968  5236.017209
# 2023-01-25  1856.025442  797.177712  5237.979655
# 2023-01-26  1883.500874  795.607706  5295.546979
# 2023-01-27  1909.275187  791.420990  5307.714539
#
# [3290 rows x 3 columns]

# %%
normClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
aapl = close_values.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-01-23  141.110001
# 2023-01-24  142.529999
# 2023-01-25  141.860001
# 2023-01-26  143.960007
# 2023-01-27  145.929993
#
# [3290 rows x 1 columns]

# %%
aapl.shift()
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2023-01-23  137.869995
# 2023-01-24  141.110001
# 2023-01-25  142.529999
# 2023-01-26  141.860001
# 2023-01-27  143.960007
#
# [3290 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2023-01-23  137.869995
# 2023-01-24  141.110001
# 2023-01-25  142.529999
# 2023-01-26  141.860001
# 2023-01-27  143.960007
#
# [3290 rows x 1 columns]

# %%
aapl['Close_lag1'] = aapl['AAPL'].shift(periods=1)
aapl
# Out:
#                   AAPL        lag1  Close_lag1
# Date
# 2010-01-04    7.643214         NaN         NaN
# 2010-01-05    7.656429    7.643214    7.643214
# 2010-01-06    7.534643    7.656429    7.656429
# 2010-01-07    7.520714    7.534643    7.534643
# 2010-01-08    7.570714    7.520714    7.520714
# ...                ...         ...         ...
# 2023-01-23  141.110001  137.869995  137.869995
# 2023-01-24  142.529999  141.110001  141.110001
# 2023-01-25  141.860001  142.529999  142.529999
# 2023-01-26  143.960007  141.860001  141.860001
# 2023-01-27  145.929993  143.960007  143.960007
#
# [3290 rows x 3 columns]

# %%
aapl.drop('lag1', axis=1, inplace=True)
aapl
# Out:
#                   AAPL  Close_lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2023-01-23  141.110001  137.869995
# 2023-01-24  142.529999  141.110001
# 2023-01-25  141.860001  142.529999
# 2023-01-26  143.960007  141.860001
# 2023-01-27  145.929993  143.960007
#
# [3290 rows x 2 columns]

# %%
aapl.drop('Close_lag1', axis=1, inplace=True)
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-01-23  141.110001
# 2023-01-24  142.529999
# 2023-01-25  141.860001
# 2023-01-26  143.960007
# 2023-01-27  145.929993
#
# [3290 rows x 1 columns]

# %%
aapl['lag1'] = aapl['AAPL'].shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2023-01-23  141.110001  137.869995
# 2023-01-24  142.529999  141.110001
# 2023-01-25  141.860001  142.529999
# 2023-01-26  143.960007  141.860001
# 2023-01-27  145.929993  143.960007
#
# [3290 rows x 2 columns]

# %%
aapl['Diff'] = aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2023-01-23  141.110001  137.869995  3.240005
# 2023-01-24  142.529999  141.110001  1.419998
# 2023-01-25  141.860001  142.529999 -0.669998
# 2023-01-26  143.960007  141.860001  2.100006
# 2023-01-27  145.929993  143.960007  1.969986
#
# [3290 rows x 3 columns]

# %%
aapl.AAPL.div(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    1.001729
# 2010-01-06    0.984094
# 2010-01-07    0.998151
# 2010-01-08    1.006648
#                 ...
# 2023-01-23    1.023500
# 2023-01-24    1.010063
# 2023-01-25    0.995299
# 2023-01-26    1.014803
# 2023-01-27    1.013684
# Length: 3290, dtype: float64

# %%
aapl['% Change'] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833    0.664833
# ...                ...         ...       ...       ...         ...
# 2023-01-23  141.110001  137.869995  3.240005  2.350044    2.350044
# 2023-01-24  142.529999  141.110001  1.419998  1.006306    1.006306
# 2023-01-25  141.860001  142.529999 -0.669998 -0.470075   -0.470075
# 2023-01-26  143.960007  141.860001  2.100006  1.480337    1.480337
# 2023-01-27  145.929993  143.960007  1.969986  1.368426    1.368426
#
# [3290 rows x 5 columns]

# %%
aapl['Diff 2'] = aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change  % Change 2    Diff 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833    0.664833  0.050000
# ...                ...         ...       ...       ...         ...       ...
# 2023-01-23  141.110001  137.869995  3.240005  2.350044    2.350044  3.240005
# 2023-01-24  142.529999  141.110001  1.419998  1.006306    1.006306  1.419998
# 2023-01-25  141.860001  142.529999 -0.669998 -0.470075   -0.470075 -0.669998
# 2023-01-26  143.960007  141.860001  2.100006  1.480337    1.480337  2.100006
# 2023-01-27  145.929993  143.960007  1.969986  1.368426    1.368426  1.969986
#
# [3290 rows x 6 columns]

# %%
aapl['% Change 2'] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change  % Change 2    Diff 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833    0.664833  0.050000
# ...                ...         ...       ...       ...         ...       ...
# 2023-01-23  141.110001  137.869995  3.240005  2.350044    2.350044  3.240005
# 2023-01-24  142.529999  141.110001  1.419998  1.006306    1.006306  1.419998
# 2023-01-25  141.860001  142.529999 -0.669998 -0.470075   -0.470075 -0.669998
# 2023-01-26  143.960007  141.860001  2.100006  1.480337    1.480337  2.100006
# 2023-01-27  145.929993  143.960007  1.969986  1.368426    1.368426  1.969986
#
# [3290 rows x 6 columns]

# %%
del aapl["Diff 2"]
aapl
# Out:
#                   AAPL        lag1      Diff  % Change  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833    0.664833
# ...                ...         ...       ...       ...         ...
# 2023-01-23  141.110001  137.869995  3.240005  2.350044    2.350044
# 2023-01-24  142.529999  141.110001  1.419998  1.006306    1.006306
# 2023-01-25  141.860001  142.529999 -0.669998 -0.470075   -0.470075
# 2023-01-26  143.960007  141.860001  2.100006  1.480337    1.480337
# 2023-01-27  145.929993  143.960007  1.969986  1.368426    1.368426
#
# [3290 rows x 5 columns]

# %%
del aapl['% Change 2']
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2023-01-23  141.110001  137.869995  3.240005  2.350044
# 2023-01-24  142.529999  141.110001  1.419998  1.006306
# 2023-01-25  141.860001  142.529999 -0.669998 -0.470075
# 2023-01-26  143.960007  141.860001  2.100006  1.480337
# 2023-01-27  145.929993  143.960007  1.969986  1.368426
#
# [3290 rows x 4 columns]

# %%
del aapl['lag1']
aapl
# Out:
#                   AAPL      Diff  % Change
# Date
# 2010-01-04    7.643214       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833
# ...                ...       ...       ...
# 2023-01-23  141.110001  3.240005  2.350044
# 2023-01-24  142.529999  1.419998  1.006306
# 2023-01-25  141.860001 -0.669998 -0.470075
# 2023-01-26  143.960007  2.100006  1.480337
# 2023-01-27  145.929993  1.969986  1.368426
#
# [3290 rows x 3 columns]

# %%
 aapl.rename(columns = {'Diff':'Difference'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL  Difference  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    0.013215  0.172893
# 2010-01-06    7.534643   -0.121786 -1.590632
# 2010-01-07    7.520714   -0.013929 -0.184871
# 2010-01-08    7.570714    0.050000  0.664833
# ...                ...         ...       ...
# 2023-01-23  141.110001    3.240005  2.350044
# 2023-01-24  142.529999    1.419998  1.006306
# 2023-01-25  141.860001   -0.669998 -0.470075
# 2023-01-26  143.960007    2.100006  1.480337
# 2023-01-27  145.929993    1.969986  1.368426
#
# [3290 rows x 3 columns]

# %%
aapl.AAPL.resample('M').last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-31    129.929993
# 2023-01-31    145.929993
# Freq: M, Name: AAPL, Length: 157, dtype: float64

# %%
aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2022-09-30   -12.097700
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30   -12.227255
# 2023-01-31    12.314324
# Freq: BM, Name: AAPL, Length: 157, dtype: float64

# %%
del aapl['% Change']
aapl
# Out:
#                   AAPL  Difference
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.013215
# 2010-01-06    7.534643   -0.121786
# 2010-01-07    7.520714   -0.013929
# 2010-01-08    7.570714    0.050000
# ...                ...         ...
# 2023-01-23  141.110001    3.240005
# 2023-01-24  142.529999    1.419998
# 2023-01-25  141.860001   -0.669998
# 2023-01-26  143.960007    2.100006
# 2023-01-27  145.929993    1.969986
#
# [3290 rows x 2 columns]

# %%
del aapl['Difference']
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2023-01-23  141.110001
# 2023-01-24  142.529999
# 2023-01-25  141.860001
# 2023-01-26  143.960007
# 2023-01-27  145.929993
#
# [3290 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2023-01-23  0.023500
# 2023-01-24  0.010063
# 2023-01-25 -0.004701
# 2023-01-26  0.014803
# 2023-01-27  0.013684
#
# [3289 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3289 entries, 2010-01-05 to 2023-01-27
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3289 non-null   float64
# dtypes: float64(1)
# memory usage: 51.4 KB

# %%
ret.plot(kind='hist', figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret= ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001061
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000327
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.018091
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.267335
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.082474
# dtype: float64

# %%
annual_stg_returns=np.sqrt(annual_var_return)
annual_stg_returns
# Out:
# AAPL    0.287182
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.287182
# dtype: float64

# %%
newTickers= ['SPY', 'AMZN', 'MSFT', 'NSRGY', 'UNH', 'WMT', 'JNJ']
souStocks = yf.download(newTickers, start = '2010-01-01', end ='2023-05-01')
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
souStocks
# Out:
#              Adj Close                                                  \
#                   AMZN         JNJ        MSFT       NSRGY         SPY
# Date
# 2010-01-04    6.695000   43.318607   23.522568   33.833179   87.483177
# 2010-01-05    6.734500   42.816299   23.530169   32.918030   87.714760
# 2010-01-06    6.612500   43.164547   23.385763   32.508263   87.776543
# 2010-01-07    6.500000   42.856495   23.142561   32.084839   88.147072
# 2010-01-08    6.676000   43.003826   23.302155   32.829243   88.440399
# ...                ...         ...         ...         ...         ...
# 2023-04-24  106.209999  161.283279  280.561371  129.369995  409.657928
# 2023-04-25  102.570000  162.761322  274.238647  128.809998  403.155090
# 2023-04-26  104.980003  160.238800  294.103027  128.710007  401.447449
# 2023-04-27  109.820000  160.613251  303.522430  127.519997  409.439484
# 2023-04-28  105.449997  161.302994  305.942047  128.259995  412.934113
#
# ...

# %%
closer = souStocks.loc[:,'Close'].copy()
dreamClose = closer.div(close.iloc[0]).mul(100)

# %%
dreamClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ret = closer.pct_change().dropna()
ret.head()
# Out:
#                 AMZN       JNJ      MSFT     NSRGY       SPY       UNH  \
# Date
# 2010-01-05  0.005900 -0.011596  0.000323 -0.027049  0.002647 -0.001586
# 2010-01-06 -0.018116  0.008134 -0.006137 -0.012448  0.000704  0.009848
# 2010-01-07 -0.017013 -0.007137 -0.010400 -0.013025  0.004221  0.038377
# 2010-01-08  0.027077  0.003438  0.006897  0.023201  0.003328 -0.009391
# 2010-01-11 -0.024041  0.000156 -0.012720  0.004161  0.001397  0.006728
#
#                  WMT
# Date
# 2010-01-05 -0.009958
# 2010-01-06 -0.002235
# 2010-01-07  0.000560
# 2010-01-08 -0.005037
# 2010-01-11  0.016501

# %%
ret.describe()
# Out:
#               AMZN          JNJ         MSFT        NSRGY          SPY  \
# count  3352.000000  3352.000000  3352.000000  3352.000000  3352.000000
# mean      0.001041     0.000334     0.000821     0.000344     0.000450
# std       0.020901     0.010653     0.016484     0.010973     0.011106
# min      -0.140494    -0.100379    -0.147390    -0.081830    -0.109424
# 25%      -0.009083    -0.004620    -0.007272    -0.005742    -0.003892
# 50%       0.000949     0.000241     0.000531     0.000499     0.000597
# 75%       0.011765     0.005708     0.009166     0.006428     0.005746
# max       0.157457     0.079977     0.142169     0.069993     0.090603
#
#                UNH          WMT
# count  3352.000000  3352.000000
# mean      0.000949     0.000381
# std       0.016055     0.012264
# min      -0.172769    -0.113758
# 25%      -0.007085    -0.005335
# 50%       0.000935     0.000506
# 75%       0.008735     0.006234
# max       0.127989     0.117085

# %%
ret.describe().T
# Out:
#         count      mean       std       min       25%       50%       75%  \
# AMZN   3352.0  0.001041  0.020901 -0.140494 -0.009083  0.000949  0.011765
# JNJ    3352.0  0.000334  0.010653 -0.100379 -0.004620  0.000241  0.005708
# MSFT   3352.0  0.000821  0.016484 -0.147390 -0.007272  0.000531  0.009166
# NSRGY  3352.0  0.000344  0.010973 -0.081830 -0.005742  0.000499  0.006428
# SPY    3352.0  0.000450  0.011106 -0.109424 -0.003892  0.000597  0.005746
# UNH    3352.0  0.000949  0.016055 -0.172769 -0.007085  0.000935  0.008735
# WMT    3352.0  0.000381  0.012264 -0.113758 -0.005335  0.000506  0.006234
#
#             max
# AMZN   0.157457
# JNJ    0.079977
# MSFT   0.142169
# NSRGY  0.069993
# SPY    0.090603
# UNH    0.127989
# WMT    0.117085

# %%
summary=ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#            mean       std
# AMZN   0.001041  0.020901
# JNJ    0.000334  0.010653
# MSFT   0.000821  0.016484
# NSRGY  0.000344  0.010973
# SPY    0.000450  0.011106
# UNH    0.000949  0.016055
# WMT    0.000381  0.012264

# %%
summary['mean']=summary['mean']*252
summary['std']=summary['std']*np.sqrt(252)
summary
# Out:
#            mean       std
# AMZN   0.262209  0.331799
# JNJ    0.084136  0.169106
# MSFT   0.206842  0.261677
# NSRGY  0.086704  0.174197
# SPY    0.113367  0.176298
# UNH    0.239162  0.254871
# WMT    0.095927  0.194683

# %%
summary.plot.scatter(x='std',y='mean',figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,'std']+0.002,summary.loc[i,'mean']+0.002),size=15)
plt.xlabel('Annual risk(std)', fontsize=15)
plt.ylabel('Annual return', fontsize=15)
plt.title('Risk/return', fontsize=25)
plt.show()

# %% [markdown]
# # Correlation and Covariance

# %%
# Comment

# %% [raw]
# ret

# %%
ret.head()
# Out:
#                 AMZN       JNJ      MSFT     NSRGY       SPY       UNH  \
# Date
# 2010-01-05  0.005900 -0.011596  0.000323 -0.027049  0.002647 -0.001586
# 2010-01-06 -0.018116  0.008134 -0.006137 -0.012448  0.000704  0.009848
# 2010-01-07 -0.017013 -0.007137 -0.010400 -0.013025  0.004221  0.038377
# 2010-01-08  0.027077  0.003438  0.006897  0.023201  0.003328 -0.009391
# 2010-01-11 -0.024041  0.000156 -0.012720  0.004161  0.001397  0.006728
#
#                  WMT
# Date
# 2010-01-05 -0.009958
# 2010-01-06 -0.002235
# 2010-01-07  0.000560
# 2010-01-08 -0.005037
# 2010-01-11  0.016501

# %%
ret.cov()
# Out:
#            AMZN       JNJ      MSFT     NSRGY       SPY       UNH       WMT
# AMZN   0.000437  0.000064  0.000196  0.000062  0.000138  0.000104  0.000064
# JNJ    0.000064  0.000113  0.000075  0.000042  0.000072  0.000083  0.000052
# MSFT   0.000196  0.000075  0.000272  0.000070  0.000139  0.000118  0.000073
# NSRGY  0.000062  0.000042  0.000070  0.000120  0.000061  0.000054  0.000035
# SPY    0.000138  0.000072  0.000139  0.000061  0.000123  0.000111  0.000063
# UNH    0.000104  0.000083  0.000118  0.000054  0.000111  0.000258  0.000063
# WMT    0.000064  0.000052  0.000073  0.000035  0.000063  0.000063  0.000150

# %%
ret.corr()
# Out:
#            AMZN       JNJ      MSFT     NSRGY       SPY       UNH       WMT
# AMZN   1.000000  0.285961  0.567851  0.270211  0.595872  0.310596  0.248633
# JNJ    0.285961  1.000000  0.428957  0.361272  0.608455  0.483578  0.400339
# MSFT   0.567851  0.428957  1.000000  0.386379  0.757279  0.447692  0.358700
# NSRGY  0.270211  0.361272  0.386379  1.000000  0.501486  0.307030  0.262896
# SPY    0.595872  0.608455  0.757279  0.501486  1.000000  0.621343  0.459308
# UNH    0.310596  0.483578  0.447692  0.307030  0.621343  1.000000  0.317423
# WMT    0.248633  0.400339  0.358700  0.262896  0.459308  0.317423  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap='Reds',annot=True, annot_kws={'size':15}, vmax=0.6)
plt.show()

# %% [markdown]
# # Simple return and log returns

# %%
df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns=['Price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns=['Price'])
#
# NameError: name 'pd' is not defined

# %%
df
